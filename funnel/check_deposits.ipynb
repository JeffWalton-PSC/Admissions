# %%
from numpy import __version__ as numpy_version
from pandas import __version__ as pandas_version

print(f"Numpy - {numpy_version}")
print(f"Pandas - {pandas_version}")
# Out:
# Numpy - 1.16.4
# Pandas - 0.24.2

# %%
import numpy as np
import pandas as pd
#import altair as alt
import datetime as dt
from pathlib import Path

# %%
# local connection information
import local_db

connection = local_db.connection()

# %%
print(f"Last Run: {dt.datetime.now()}")

today = dt.datetime.now().strftime("%Y%m%d")
year = 2019

fall_term = f"{year}.Fall"
print(f"{fall_term}")
# Out:
# Last Run: 2019-07-08 15:22:58.801531
# 2019.Fall

# %%
sql_str = (
    "SELECT DISTINCT "
    + "PEOPLE_CODE_ID, "
    + "ACADEMIC_YEAR, "
    + "ACADEMIC_TERM, "
    + "FIELD_ID, "
    + "FIELD_DATE "
    + "FROM [Campus6].[dbo].[STAGEHISTORY] "
    + f"WHERE ACADEMIC_YEAR='{year}' "
    + "and ACADEMIC_TERM='FALL' "
    + "and FIELD_ID in (10,49,50,39,13) "
    + "ORDER BY PEOPLE_CODE_ID, FIELD_DATE, FIELD_ID "
)

df_stghist = pd.read_sql_query(sql_str, connection)

print(df_stghist.shape)
# Out:
# (525, 5)

# %%
df_stghist.head()
# Out:
#   PEOPLE_CODE_ID ACADEMIC_YEAR ACADEMIC_TERM  FIELD_ID FIELD_DATE
# 0     P000035178          2019          FALL        10 2019-04-03
# 1     P000035178          2019          FALL        50 2019-04-03
# 2     P000043954          2019          FALL        10 2019-05-08
# 3     P000043954          2019          FALL        50 2019-05-08
# 4     P000047813          2019          FALL        10 2019-03-20

# %%
df_stghist.loc[((df_stghist['FIELD_ID']==10)|(df_stghist['FIELD_ID']==50))]
# Out:
#     PEOPLE_CODE_ID ACADEMIC_YEAR ACADEMIC_TERM  FIELD_ID FIELD_DATE
# 0       P000035178          2019          FALL        10 2019-04-03
# 1       P000035178          2019          FALL        50 2019-04-03
# 2       P000043954          2019          FALL        10 2019-05-08
# 3       P000043954          2019          FALL        50 2019-05-08
# 4       P000047813          2019          FALL        10 2019-03-20
# 5       P000047813          2019          FALL        50 2019-03-20
# 6       P000050419          2019          FALL        10 2019-04-22
# 7       P000050419          2019          FALL        50 2019-04-22
# 8       P000052458          2019          FALL        10 2019-04-11
# 9       P000052458          2019          FALL        50 2019-04-11
# 10      P000053525          2019          FALL        10 2019-05-16
# 11      P000053525          2019          FALL        50 2019-05-16
# 12      P000053594          2019          FALL        10 2019-05-28
# 13      P000053594          2019          FALL        50 2019-05-28
# 14      P000053667          2019          FALL        10 2019-04-23
# 16      P000053682          2019          FALL        10 2019-04-11
# 17      P000053682          2019          FALL        50 2019-04-11
# 19      P000054046          2019          FALL        10 2019-02-27
# 20      P000054046          2019          FALL        50 2019-02-27
# 21      P000054054          2019          FALL        10 2019-05-01
# 22      P000054054          2019          FALL        50 2019-05-01
# 23      P000054144          2019          FALL        10 2019-03-20
# 24      P000054144          2019          FALL        50 2019-03-20
# 26      P000054166          2019          FALL        10 2019-04-09
# 27      P000054166          2019          FALL        50 2019-04-09
# 28      P000054276          2019          FALL        10 2019-03-20
# 29      P000054276          2019          FALL        50 2019-03-20
# 30      P000054664          2019          FALL        10 2019-07-03
# 31      P000054664          2019          FALL        50 2019-07-03
# 32      P000054845          2019          FALL        10 2019-04-01
# ..             ...           ...           ...       ...        ...
# 489     P000057001          2019          FALL        10 2019-06-05
# 491     P000057014          2019          FALL        10 2019-05-13
# 492     P000057014          2019          FALL        50 2019-05-13
# 493     P000057020          2019          FALL        10 2019-06-20
# 494     P000057020          2019          FALL        50 2019-06-20
# 495     P000057025          2019          FALL        10 2019-06-25
# 496     P000057025          2019          FALL        50 2019-06-25
# 497     P000057028          2019          FALL        10 2019-06-04
# 498     P000057028          2019          FALL        50 2019-06-04
# 499     P000057029          2019          FALL        10 2019-05-23
# 501     P000057031          2019          FALL        10 2019-06-25
# 502     P000057031          2019          FALL        50 2019-06-25
# 503     P000057032          2019          FALL        10 2019-06-10
# 504     P000057032          2019          FALL        50 2019-06-10
# 505     P000057033          2019          FALL        10 2019-06-13
# 506     P000057033          2019          FALL        50 2019-06-19
# 507     P000057044          2019          FALL        10 2019-06-12
# 508     P000057044          2019          FALL        50 2019-06-12
# 509     P000057050          2019          FALL        10 2019-07-01
# 510     P000057050          2019          FALL        50 2019-07-01
# 511     P000057066          2019          FALL        10 2019-06-09
# 512     P000057066          2019          FALL        50 2019-06-09
# 513     P000057072          2019          FALL        10 2019-07-02
# 515     P000057090          2019          FALL        10 2019-06-17
# 516     P000057090          2019          FALL        50 2019-06-17
# 517     P000057092          2019          FALL        10 2019-06-15
# 519     P000057101          2019          FALL        10 2019-06-19
# 521     P000057117          2019          FALL        10 2019-06-28
# 523     P000057125          2019          FALL        10 2019-07-03
# 524     P000057125          2019          FALL        50 2019-07-03
#
# [482 rows x 5 columns]

# %% [markdown]
# ### Use admissions.py code

# %%
# read VWSSTAGERANKING data
sql_str = (
    "SELECT STAGERANKING_ID, field_name, field_value "
    + "FROM VWSSTAGERANKING WHERE "
    + "status = 'A' "
)
stgrnk = pd.read_sql_query(sql_str, connection)

# read STAGEHISTORY data
sql_str = (
    "SELECT PEOPLE_CODE_ID, ACADEMIC_YEAR, ACADEMIC_TERM, "
    + "ACADEMIC_SESSION, FIELD_ID, FIELD_DATE, HIDDEN "
    + "FROM STAGEHISTORY WHERE "
    + "HIDDEN = 'N' "
    + f"AND ACADEMIC_YEAR = '{year}' "
    + "and ACADEMIC_TERM='FALL' "
)
stg_hist = pd.read_sql_query(sql_str, connection)

stg_hist = stg_hist.rename(columns={"FIELD_DATE": "create_date"})
stage_data = pd.merge(
    stg_hist, stgrnk, left_on=["FIELD_ID"], right_on=["STAGERANKING_ID"], how="left"
)
keep_fields = [
    "PEOPLE_CODE_ID",
    "ACADEMIC_YEAR",
    "ACADEMIC_TERM",
    "ACADEMIC_SESSION",
    "field_name",
    "field_value",
    "create_date",
]
stage_data = stage_data.loc[~stage_data["create_date"].isnull(), keep_fields]

print(stage_data.shape)
# Out:
# (4907, 7)

# %%
# read ACADEMIC data
sql_str = (
    "SELECT PEOPLE_CODE_ID, ACADEMIC_YEAR, ACADEMIC_TERM, "
    + "ACADEMIC_SESSION, POPULATION, INQUIRY_FLAG, "
    + "APPLICATION_FLAG, APPLICATION_DATE, "
    + "APP_STATUS, APP_STATUS_DATE, "
    + "APP_DECISION, APP_DECISION_DATE "
    + "FROM ACADEMIC WHERE "
    + f"ACADEMIC_YEAR >= '{year}' "
)
academic = pd.read_sql_query(sql_str, connection)

app_data = academic.loc[
    ~(academic["POPULATION"].isin(["ADVSTU", "NOND"]))
    & ((academic["INQUIRY_FLAG"] == "Y") | (academic["APPLICATION_FLAG"] == "Y"))
]

applied = app_data[app_data["APP_STATUS"].notnull()].rename(
    columns={"APP_STATUS": "field_value", "APP_STATUS_DATE": "create_date"}
)
applied.loc[:, "field_name"] = "Application Status"
applied = applied.loc[~applied["create_date"].isnull(), keep_fields]

accepted = app_data[app_data["APP_DECISION"].notnull()].rename(
    columns={"APP_DECISION": "field_value", "APP_DECISION_DATE": "create_date"}
)
accepted.loc[:, "field_name"] = "Application Decision"
accepted = accepted.loc[~accepted["create_date"].isnull(), keep_fields]

# %%
# stack Stage History, Academic Applied and Academic Accepted
adm_df = stage_data.append(applied).append(accepted)

adm_df = adm_df.loc[
    (
        (adm_df["ACADEMIC_TERM"].isin(["FALL", "SPRING"]))
        & (adm_df["ACADEMIC_SESSION"] == "MAIN")
        & (adm_df["ACADEMIC_YEAR"] == f"{year}")
    )
]

# %%
print(adm_df.shape)
# Out:
# (5526, 7)

# %%
print(adm_df.columns)
# Out:
# Index(['PEOPLE_CODE_ID', 'ACADEMIC_YEAR', 'ACADEMIC_TERM', 'ACADEMIC_SESSION',
#        'field_name', 'field_value', 'create_date'],
#       dtype='object')

# %%
# create new fields
adm_df["year_term"] = (
    adm_df["ACADEMIC_YEAR"] + "." + adm_df["ACADEMIC_TERM"].str.title()
)

# %%
adm_df = adm_df.loc[(adm_df["year_term"]==fall_term)]
print(adm_df.shape)
# Out:
# (5466, 8)

# %%
adm_keep_values = [
    "300",
    "ACC",
    "ACXL",
    "CANC",
    "DEF",
    "DEFR",
    "DENY",
    "DPAC",
    "TRDP",
    "TRPD",
    "TRNS",
    "WAIT",
    "500",
    "PEND",
    "COMP",
]
adm_keep_cols = ["PEOPLE_CODE_ID", "year_term", "create_date", "field_value"]
adm_df = adm_df.loc[(adm_df["field_value"].isin(adm_keep_values)), adm_keep_cols]

# %%
print(adm_df.shape)
# Out:
# (4506, 4)

# %%
adm_df.head()
# Out:
#    PEOPLE_CODE_ID  year_term create_date field_value
# 10     P000055649  2019.Fall  2018-08-31         300
# 11     P000055649  2019.Fall  2018-10-10         ACC
# 12     P000055839  2019.Fall  2018-09-11         300
# 13     P000055839  2019.Fall  2018-10-09         ACC
# 14     P000055840  2019.Fall  2018-08-21         300

# %%
# admissions status table
admission_status = {
    "300": "1_Applied",
    "ACC": "2_Accepted",
    "ACXL": "4_Canceled",
    "CANC": "4_Canceled",
    "DEF": "4_Canceled",
    "DEFR": "4_Canceled",
    "DENY": "4_Canceled",
    "DPAC": "3_Deposited",
    "TRDP": "3_Deposited",
    "TRPD": "3_Deposited",
    "TRNS": "2_Accepted",
    "WAIT": "2_Accepted",
    "500": "3_Deposited",
    "PEND": "1_Applied",
    "COMP": "1_Applied",
}
adm_stat = pd.DataFrame(
    list(admission_status.items()), columns=["field_value", "admission_status"]
)

adm_stat
# Out:
#    field_value admission_status
# 0          300        1_Applied
# 1          ACC       2_Accepted
# 2         ACXL       4_Canceled
# 3         CANC       4_Canceled
# 4          DEF       4_Canceled
# 5         DEFR       4_Canceled
# 6         DENY       4_Canceled
# 7         DPAC      3_Deposited
# 8         TRDP      3_Deposited
# 9         TRPD      3_Deposited
# 10        TRNS       2_Accepted
# 11        WAIT       2_Accepted
# 12         500      3_Deposited
# 13        PEND        1_Applied
# 14        COMP        1_Applied

# %%
adm_df1 = (
    pd.merge(adm_df, adm_stat, on=["field_value"], how="left")
    .drop(["field_value"], axis=1)
    .drop_duplicates(
        ["PEOPLE_CODE_ID", "year_term", "create_date", "admission_status"]
    )
)

adm_df1.head()
# Out:
#   PEOPLE_CODE_ID  year_term create_date admission_status
# 0     P000055649  2019.Fall  2018-08-31        1_Applied
# 1     P000055649  2019.Fall  2018-10-10       2_Accepted
# 2     P000055839  2019.Fall  2018-09-11        1_Applied
# 3     P000055839  2019.Fall  2018-10-09       2_Accepted
# 4     P000055840  2019.Fall  2018-08-21        1_Applied

# %%
adm_df1 = adm_df1.sort_values(
    ["year_term", "PEOPLE_CODE_ID", "admission_status", "create_date"]
).drop_duplicates(["year_term", "PEOPLE_CODE_ID", "admission_status"], keep="first")

# %%
adm_df1 = adm_df1[["PEOPLE_CODE_ID", "admission_status", "create_date"]]

adm_df1["status"] = 1

# %%
print(adm_df1.shape)
# Out:
# (2199, 4)

# %%
print(adm_df1.columns)
# Out:
# Index(['PEOPLE_CODE_ID', 'admission_status', 'create_date', 'status'], dtype='object')

# %%
adm_df1.head()
# Out:
#      PEOPLE_CODE_ID admission_status create_date  status
# 1570     P000035178        1_Applied  2019-02-13       1
# 1571     P000035178       2_Accepted  2019-03-07       1
# 1742     P000035178      3_Deposited  2019-04-03       1
# 1572     P000043954        1_Applied  2019-03-15       1
# 1573     P000043954       2_Accepted  2019-03-18       1

# %%
e = adm_df1.pivot_table(
    index=["PEOPLE_CODE_ID"],
    columns=["admission_status"],
    values=["status"],
)
e = e.fillna(0)

e.columns = e.columns.droplevel()

# %%
e
# Out:
# admission_status  1_Applied  2_Accepted  3_Deposited  4_Canceled
# PEOPLE_CODE_ID
# P000035178              1.0         1.0          1.0         0.0
# P000043954              1.0         1.0          1.0         0.0
# P000047813              1.0         1.0          1.0         0.0
# P000050419              0.0         0.0          1.0         0.0
# P000052458              0.0         0.0          1.0         0.0
# P000053525              0.0         0.0          1.0         0.0
# P000053594              0.0         0.0          1.0         0.0
# P000053667              0.0         0.0          1.0         0.0
# P000053682              0.0         0.0          1.0         0.0
# P000054046              0.0         0.0          1.0         0.0
# P000054054              0.0         0.0          1.0         0.0
# P000054144              1.0         1.0          1.0         0.0
# P000054166              0.0         0.0          1.0         0.0
# P000054276              1.0         1.0          1.0         0.0
# P000054664              1.0         1.0          1.0         0.0
# P000054845              0.0         0.0          1.0         0.0
# P000055006              0.0         0.0          1.0         0.0
# P000055285              0.0         0.0          1.0         0.0
# P000055309              1.0         1.0          1.0         0.0
# P000055328              1.0         1.0          0.0         0.0
# P000055484              1.0         1.0          1.0         0.0
# P000055486              0.0         0.0          1.0         0.0
# P000055499              0.0         0.0          1.0         0.0
# P000055602              1.0         1.0          0.0         0.0
# P000055610              0.0         0.0          1.0         0.0
# P000055614              1.0         1.0          1.0         0.0
# P000055649              1.0         1.0          1.0         0.0
# P000055661              1.0         1.0          0.0         0.0
# P000055681              0.0         0.0          1.0         1.0
# P000055757              0.0         0.0          1.0         0.0
# ...                     ...         ...          ...         ...
# P000057088              1.0         1.0          0.0         0.0
# P000057090              1.0         1.0          1.0         0.0
# P000057091              1.0         1.0          0.0         0.0
# P000057092              1.0         1.0          1.0         0.0
# P000057093              1.0         1.0          0.0         0.0
# P000057094              1.0         1.0          0.0         0.0
# P000057095              1.0         1.0          0.0         0.0
# P000057096              1.0         1.0          0.0         0.0
# P000057098              1.0         1.0          0.0         0.0
# P000057099              1.0         1.0          0.0         0.0
# P000057100              1.0         1.0          0.0         0.0
# P000057101              1.0         1.0          1.0         0.0
# P000057103              1.0         1.0          0.0         0.0
# P000057104              1.0         1.0          0.0         0.0
# P000057107              1.0         1.0          0.0         0.0
# P000057108              1.0         1.0          0.0         0.0
# P000057117              0.0         0.0          1.0         0.0
# P000057118              1.0         1.0          0.0         0.0
# P000057119              1.0         1.0          0.0         0.0
# P000057120              1.0         1.0          0.0         0.0
# P000057121              1.0         1.0          0.0         0.0
# P000057122              1.0         1.0          0.0         0.0
# P000057123              1.0         1.0          0.0         0.0
# P000057124              1.0         1.0          0.0         0.0
# P000057125              1.0         1.0          1.0         0.0
# P000057126              1.0         1.0          0.0         0.0
# P000057127              1.0         1.0          0.0         0.0
# P000057128              1.0         1.0          0.0         0.0
# P000057130              1.0         1.0          0.0         0.0
# P000057131              1.0         1.0          0.0         0.0
#
# [1005 rows x 4 columns]

# %%
dep = e.loc[(e["3_Deposited"]==1)]

# %%
active_dep = e.loc[(e["3_Deposited"]==1)&(~(e["4_Canceled"]==1))]
print(active_dep.shape)
active_dep.head()
# Out:
# (245, 4)
# admission_status  1_Applied  2_Accepted  3_Deposited  4_Canceled
# PEOPLE_CODE_ID
# P000035178              1.0         1.0          1.0         0.0
# P000043954              1.0         1.0          1.0         0.0
# P000047813              1.0         1.0          1.0         0.0
# P000050419              0.0         0.0          1.0         0.0
# P000052458              0.0         0.0          1.0         0.0

# %%
sql_str = (
    f"""
SELECT [PEOPLE].[PEOPLE_CODE_ID],
	[PEOPLE].[LAST_NAME],
	[PEOPLE].[FIRST_NAME],
	[PEOPLE].[MIDDLE_NAME],
	[PEOPLE].[BIRTH_DATE],
	[PEOPLE].[GOVERNMENT_ID],
	[ADDRESS].[EMAIL_ADDRESS],
	[ADDRESS].[ADDRESS_TYPE],
	[ADDRESS].[ADDRESS_LINE_1],
	[ADDRESS].[CITY],
	[ADDRESS].[STATE],
    [ADDRESS].[COUNTRY], 
	[ADDRESS].[ZIP_CODE],
	[ACADEMIC].[CREDITS],
	[ACADEMIC].[DEGREE],
	[ACADEMIC].[CURRICULUM],
	[ACADEMIC].[ACADEMIC_YEAR],
	[ACADEMIC].[ACADEMIC_TERM],
	[ACADEMIC].[ADMIT_YEAR],
	[ACADEMIC].[ADMIT_TERM],
	[ACADEMIC].[APP_STATUS_DATE],
	[ACADEMIC].[APP_STATUS],
	[ACADEMIC].[COLLEGE_ATTEND],
	[ACADEMIC].[REVISION_DATE],
	[ACADEMIC].[REVISION_TIME],
	[ACADEMIC].[REVISION_OPID]
FROM [Campus6].[dbo].[ACADEMIC], [Campus6].[dbo].PEOPLE, [Campus6].[dbo].ADDRESS
WHERE ( 
	[ACADEMIC].[PEOPLE_CODE_ID] = [ADDRESS].[PEOPLE_ORG_CODE_ID] AND
	[ACADEMIC].[PEOPLE_ID] = [PEOPLE].[PEOPLE_ID] 
	  ) AND
	  (  
	 [ACADEMIC].[ADMIT_YEAR] = N'2019'  and
	 [ACADEMIC].[ADMIT_TERM] = N'fall'  And
	 [ACADEMIC].[ACADEMIC_YEAR] = N'{year}'  And
	 [ACADEMIC].[ACADEMIC_TERM] = N'fall'  And
	 [ADDRESS].[ADDRESS_TYPE] = N'HOME'  and
	 [ACADEMIC].[APP_STATUS] = N'500'  and
	 [ACADEMIC].[ACADEMIC_SESSION] = N''   and
     (ACADEMIC.APP_DECISION = 'DPAC' or
	  ACADEMIC.APP_DECISION = 'TRDP')
      )
--	  and (GOVERNMENT_ID is null or GOVERNMENT_ID='' or GOVERNMENT_ID=' ')
GROUP BY [PEOPLE].[PEOPLE_CODE_ID], 
         [PEOPLE].[LAST_NAME], 
		 [PEOPLE].[FIRST_NAME], 
		 [PEOPLE].[MIDDLE_NAME], 
		 [PEOPLE].[BIRTH_DATE], 
		 [PEOPLE].[GOVERNMENT_ID],
		 [ADDRESS].[EMAIL_ADDRESS], 
		 [ADDRESS].[ADDRESS_TYPE], 
		 [ADDRESS].[ADDRESS_LINE_1], 
		 [ADDRESS].[CITY], 
		 [ADDRESS].[STATE], 
		 [ADDRESS].[COUNTRY], 
		 [ADDRESS].[ZIP_CODE], 
		 [ACADEMIC].[CREDITS], 
		 [ACADEMIC].[DEGREE], 
		 [ACADEMIC].[CURRICULUM], 
		 [ACADEMIC].[ACADEMIC_YEAR], 
		 [ACADEMIC].[ACADEMIC_TERM], 
		 [ACADEMIC].[ADMIT_YEAR],
		 [ACADEMIC].[ADMIT_TERM], 
		 [ACADEMIC].[APP_STATUS_DATE], 
		 [ACADEMIC].[APP_STATUS],
		 [ACADEMIC].[COLLEGE_ATTEND],
		 [ACADEMIC].[REVISION_DATE],
		 [ACADEMIC].[REVISION_TIME],
		 [ACADEMIC].[REVISION_OPID]


ORDER BY 
--		[ACADEMIC].[APP_STATUS_DATE],
		[PEOPLE].[LAST_NAME]
--		[ACADEMIC].[REVISION_DATE],
--	    [ACADEMIC].[REVISION_TIME]
    """
)

df_deposits = pd.read_sql_query(sql_str, connection)

print(df_deposits.shape)
df_deposits.head()
# Out:
# (245, 26)
#   PEOPLE_CODE_ID LAST_NAME FIRST_NAME MIDDLE_NAME BIRTH_DATE GOVERNMENT_ID  \
# 0     P000055913     Abele      Maxon             2000-07-24     070907364
# 1     P000055865   Adamiec    Lillian             2000-12-05     020845664
# 2     P000056876       Ahl    Maureen      Elliot 1999-01-14     086884068
# 3     P000056203      Aini    Patrick     Joeseph 2000-08-13     070905130
# 4     P000056509   Akabati     Azanui     Stanley 1999-03-04     999956509
#
#              EMAIL_ADDRESS ADDRESS_TYPE         ADDRESS_LINE_1  \
# 0    mabele@paulsmiths.edu         HOME  4472 Lake Shore Drive
# 1  ladamiec@paulsmiths.edu         HOME       26 Kenney Street
# 2      mahl@paulsmiths.edu         HOME   212 Meadowbrook Road
# 3     paini@paulsmiths.edu         HOME          1 Bush Street
# 4  aakabati@paulsmiths.edu         HOME    Below Ccast Bambili
#
#                 CITY  ... ACADEMIC_YEAR ACADEMIC_TERM ADMIT_YEAR  ADMIT_TERM  \
# 0      Diamond Point  ...          2019          FALL       2019        FALL
# 1        New Bedford  ...          2019          FALL       2019        FALL
# 2   Saratoga Springs  ...          2019          FALL       2019        FALL
# 3            Arkport  ...          2019          FALL       2019        FALL
# 4  Bamenda, Cameroon  ...          2019          FALL       2019        FALL
#
#   APP_STATUS_DATE APP_STATUS COLLEGE_ATTEND REVISION_DATE  \
# 0      2018-11-20        500            FTF    2019-06-27
# 1      2019-02-14        500            FTF    2019-06-13
# 2      2019-06-27        500           TRAN    2019-07-01
# 3      2019-06-18        500            FTF    2019-06-20
# 4      2019-06-07        500            FTF    2019-06-12
#
#             REVISION_TIME REVISION_OPID
# 0 1900-01-01 14:46:39.577       CARLINJ
# 1 1900-01-01 09:38:40.190       CARLINJ
# 2 1900-01-01 09:21:48.773       CARLINJ
# 3 1900-01-01 16:05:11.100       CARLINJ
# 4 1900-01-01 14:25:36.597       CARLINJ
#
# [5 rows x 26 columns]

# %%
cmp = (
    pd.merge(active_dep, df_deposits, on=["PEOPLE_CODE_ID"], how="outer", indicator=True)
)

print(cmp.shape)
cmp
# Out:
# (245, 31)
#     PEOPLE_CODE_ID  1_Applied  2_Accepted  3_Deposited  4_Canceled  \
# 0       P000035178        1.0         1.0          1.0         0.0
# 1       P000043954        1.0         1.0          1.0         0.0
# 2       P000047813        1.0         1.0          1.0         0.0
# 3       P000050419        0.0         0.0          1.0         0.0
# 4       P000052458        0.0         0.0          1.0         0.0
# 5       P000053525        0.0         0.0          1.0         0.0
# 6       P000053594        0.0         0.0          1.0         0.0
# 7       P000053667        0.0         0.0          1.0         0.0
# 8       P000053682        0.0         0.0          1.0         0.0
# 9       P000054046        0.0         0.0          1.0         0.0
# 10      P000054054        0.0         0.0          1.0         0.0
# 11      P000054144        1.0         1.0          1.0         0.0
# 12      P000054166        0.0         0.0          1.0         0.0
# 13      P000054276        1.0         1.0          1.0         0.0
# 14      P000054664        1.0         1.0          1.0         0.0
# 15      P000054845        0.0         0.0          1.0         0.0
# 16      P000055006        0.0         0.0          1.0         0.0
# 17      P000055285        0.0         0.0          1.0         0.0
# 18      P000055309        1.0         1.0          1.0         0.0
# 19      P000055484        1.0         1.0          1.0         0.0
# 20      P000055486        0.0         0.0          1.0         0.0
# 21      P000055499        0.0         0.0          1.0         0.0
# 22      P000055610        0.0         0.0          1.0         0.0
# 23      P000055614        1.0         1.0          1.0         0.0
# 24      P000055649        1.0         1.0          1.0         0.0
# 25      P000055757        0.0         0.0          1.0         0.0
# 26      P000055762        0.0         0.0          1.0         0.0
# 27      P000055782        1.0         1.0          1.0         0.0
# 28      P000055823        0.0         0.0          1.0         0.0
# 29      P000055840        1.0         1.0          1.0         0.0
# ..             ...        ...         ...          ...         ...
# 215     P000056915        1.0         1.0          1.0         0.0
# 216     P000056933        1.0         1.0          1.0         0.0
# 217     P000056951        1.0         1.0          1.0         0.0
# 218     P000056952        1.0         1.0          1.0         0.0
# 219     P000056954        0.0         0.0          1.0         0.0
# 220     P000056964        1.0         1.0          1.0         0.0
# 221     P000056965        1.0         1.0          1.0         0.0
# 222     P000056973        1.0         1.0          1.0         0.0
# 223     P000056987        1.0         1.0          1.0         0.0
# 224     P000056990        1.0         1.0          1.0         0.0
# 225     P000056995        1.0         1.0          1.0         0.0
# 226     P000056998        0.0         0.0          1.0         0.0
# 227     P000057001        1.0         1.0          1.0         0.0
# 228     P000057014        1.0         1.0          1.0         0.0
# 229     P000057020        1.0         1.0          1.0         0.0
# 230     P000057025        1.0         1.0          1.0         0.0
# 231     P000057028        1.0         1.0          1.0         0.0
# 232     P000057029        1.0         1.0          1.0         0.0
# 233     P000057031        1.0         1.0          1.0         0.0
# 234     P000057032        1.0         1.0          1.0         0.0
# 235     P000057033        1.0         1.0          1.0         0.0
# 236     P000057044        1.0         1.0          1.0         0.0
# 237     P000057050        1.0         1.0          1.0         0.0
# 238     P000057066        1.0         1.0          1.0         0.0
# 239     P000057072        1.0         1.0          1.0         0.0
# 240     P000057090        1.0         1.0          1.0         0.0
# 241     P000057092        1.0         1.0          1.0         0.0
# 242     P000057101        1.0         1.0          1.0         0.0
# 243     P000057117        0.0         0.0          1.0         0.0
# 244     P000057125        1.0         1.0          1.0         0.0
#
#            LAST_NAME   FIRST_NAME    MIDDLE_NAME BIRTH_DATE GOVERNMENT_ID  \
# 0             Palmer         Jack                1996-06-29     055866222
# 1                Hoy     Savannah           Anne 1996-08-16     633543612
# 2           Lockwood     Danielle        Kathryn 2001-09-23     135114783
# 3           Gosselin        Julia            Ann 1998-03-08     008828670
# 4         Squillante  Christopher         Martin 1998-05-22     036669894
# 5            Sanborn        Jaden          Emily 1999-05-10     003924985
# 6           Cancilla      Abigail      Elizabeth 1999-04-01     095885102
# 7            Gleason         Drew         Samuel 1999-02-10     089885627
# 8            Johnson       Jordan        Nesmith 1999-02-24     009826569
# 9           Hardeman      Meaghan              E 1999-01-08     086883458
# 10           Backman       Daniel         Philip 1999-03-24     094880526
# 11   Sprott-Scribner      Zachary                1999-11-29     123887817
# 12        Charlebois      Abigail           Lane 1999-10-01     117888186
# 13          Sleicher       Lauren         Nicole 1999-04-07     098888175
# 14           Jaquith       Yelena           Joan 2001-02-22     168804803
# 15             Judge       Stacey                1993-10-18     098827770
# 16           Griffin        David        Bruneau 2000-06-29     066906461
# 17            Cowser      Jackson        Duffley 2000-09-13     073900654
# 18             Ewalt         John        Vincent 2001-03-11     094907686
# 19          McKinley         Kara         Karina 2000-12-06     113908115
# 20            Nadell       Tobias           Wood 1998-11-20     080888793
# 21            Cohen          Adam         Marcus 2000-03-10     153084632
# 22             Klein      Daniel         Francis 1998-01-13     216514496
# 23              Zogg         Mark           Ryan 2001-09-30     122904402
# 24            Wilson       Brooke           Lynn 2000-11-18     651168978
# 25            Finley     Larenzo         D'Wayne 1999-09-11     631689932
# 26           Dernier        Bryce                1996-10-21     594635262
# 27          Lechicky      Michael              T 2001-08-23     156080127
# 28             Corby     Nicholas          David 1997-05-22     151027998
# 29          Sponsler      Madalyn            Kay 2000-12-27     274061426
# ..               ...          ...            ...        ...           ...
# 215          Griffin       Dakota         Jordan 1994-09-08     058843343
# 216            Brock      Abigail           Jean 2001-04-10     024846502
# 217            Aubin         Dawn         Nicole 1986-01-10     574788504
# 218           Klauer        James                2001-12-07     008862515
# 219            Hayes        Jesse         Daniel 1985-12-16     085707369
# 220             Deng       Xiaohe                2000-06-07     999956964
# 221            Chubb       Andrew         Joseph 1999-05-11     053922529
# 222            Bruce        Dylan           Karl 2001-06-07          None
# 223             Tuft        Riley          Elise 2000-09-05     477378844
# 224        Alexander        Tenya        Jennell 2001-04-09     170802184
# 225             Sale       Adison                1998-04-02     592759468
# 226       Zakrzewski     Nicholas          James 2001-10-04     123909305
# 227          Sharrow  Kaiennahawi                1998-10-06     442130350
# 228            Hoppe    Alexander                2001-04-24     148082996
# 229            Roque      Steven                 2001-01-11     087907997
# 230          Basista      Matthew           Paul 1999-01-26     089885166
# 231           Teague        Ethan          Shane 2000-11-22     009843599
# 232         Crescent       Ethan       Alexander 1998-09-13     073884926
# 233    VanValkenburg        Emily         Elaine 2001-01-31     089902958
# 234             John      Abigail          Reece 2001-10-18     125903133
# 235          Spencer         Evan          Reece 1994-06-15     009786809
# 236          Henrich       Rachel       Victoria 1984-03-29     087780617
# 237             Ruiz        Edgar        Gerardo 2001-08-28     120908041
# 238          Cushman     Sunshine  Alexis  LaVon 2001-09-04     772052121
# 239       Schauffler         Erik        William 2000-06-21     066907875
# 240          Anguzza        David         Andrew 2000-12-03     082907331
# 241           Cooper        David       Harrison 2001-09-29     122904400
# 242             Lipe       Samuel          James 1998-08-21     077885891
# 243        Hemingway        Jared                2001-08-06     115900235
# 244           Peters     Samantha                2000-05-04     297046748
#
#      ... ACADEMIC_TERM ADMIT_YEAR ADMIT_TERM APP_STATUS_DATE APP_STATUS  \
# 0    ...          FALL       2019       FALL      2019-04-03        500
# 1    ...          FALL       2019       FALL      2019-05-08        500
# 2    ...          FALL       2019       FALL      2019-03-20        500
# 3    ...          FALL       2019       FALL      2019-04-22        500
# 4    ...          FALL       2019       FALL      2019-04-11        500
# 5    ...          FALL       2019       FALL      2019-05-16        500
# 6    ...          FALL       2019       FALL      2019-05-28        500
# 7    ...          FALL       2019       FALL      2019-04-23        500
# 8    ...          FALL       2019       FALL      2019-04-11        500
# 9    ...          FALL       2019       FALL      2019-02-27        500
# 10   ...          FALL       2019       FALL      2019-05-01        500
# 11   ...          FALL       2019       FALL      2019-03-20        500
# 12   ...          FALL       2019       FALL      2019-04-09        500
# 13   ...          FALL       2019       FALL      2019-03-20        500
# 14   ...          FALL       2019       FALL      2019-07-03        500
# 15   ...          FALL       2019       FALL      2019-04-01        500
# 16   ...          FALL       2019       FALL      2019-03-28        500
# 17   ...          FALL       2019       FALL      2019-02-24        500
# 18   ...          FALL       2019       FALL      2019-03-22        500
# 19   ...          FALL       2019       FALL      2019-03-13        500
# 20   ...          FALL       2019       FALL      2019-01-08        500
# 21   ...          FALL       2019       FALL      2019-03-29        500
# 22   ...          FALL       2019       FALL      2019-04-08        500
# 23   ...          FALL       2019       FALL      2019-03-20        500
# 24   ...          FALL       2019       FALL      2019-04-29        500
# 25   ...          FALL       2019       FALL      2019-05-31        500
# 26   ...          FALL       2019       FALL      2019-02-20        500
# 27   ...          FALL       2019       FALL      2019-05-02        500
# 28   ...          FALL       2019       FALL      2019-05-17        500
# 29   ...          FALL       2019       FALL      2019-03-28        500
# ..   ...           ...        ...        ...             ...        ...
# 215  ...          FALL       2019       FALL      2019-05-08        500
# 216  ...          FALL       2019       FALL      2019-05-02        500
# 217  ...          FALL       2019       FALL      2019-07-01        500
# 218  ...          FALL       2019       FALL      2019-06-29        500
# 219  ...          FALL       2019       FALL      2019-05-08        500
# 220  ...          FALL       2019       FALL      2019-05-08        500
# 221  ...          FALL       2019       FALL      2019-05-28        500
# 222  ...          FALL       2019       FALL      2019-06-10        500
# 223  ...          FALL       2019       FALL      2019-05-06        500
# 224  ...          FALL       2019       FALL      2019-06-07        500
# 225  ...          FALL       2019       FALL      2019-06-03        500
# 226  ...          FALL       2019       FALL      2019-05-01        500
# 227  ...          FALL       2019       FALL      2019-06-05        500
# 228  ...          FALL       2019       FALL      2019-05-13        500
# 229  ...          FALL       2019       FALL      2019-06-20        500
# 230  ...          FALL       2019       FALL      2019-06-25        500
# 231  ...          FALL       2019       FALL      2019-06-04        500
# 232  ...          FALL       2019       FALL      2019-05-23        500
# 233  ...          FALL       2019       FALL      2019-06-25        500
# 234  ...          FALL       2019       FALL      2019-06-10        500
# 235  ...          FALL       2019       FALL      2019-06-13        500
# 236  ...          FALL       2019       FALL      2019-06-12        500
# 237  ...          FALL       2019       FALL      2019-07-01        500
# 238  ...          FALL       2019       FALL      2019-06-09        500
# 239  ...          FALL       2019       FALL      2019-07-02        500
# 240  ...          FALL       2019       FALL      2019-06-17        500
# 241  ...          FALL       2019       FALL      2019-06-15        500
# 242  ...          FALL       2019       FALL      2019-06-19        500
# 243  ...          FALL       2019       FALL      2019-06-28        500
# 244  ...          FALL       2019       FALL      2019-07-03        500
#
#     COLLEGE_ATTEND REVISION_DATE           REVISION_TIME REVISION_OPID _merge
# 0             TRAN    2019-06-13 1900-01-01 14:53:22.467       CARLINJ   both
# 1             TRAN    2019-06-21 1900-01-01 15:36:45.530       JWALTON   both
# 2              FTF    2019-04-29 1900-01-01 13:53:14.703       CARLINJ   both
# 3             TRAN    2019-06-20 1900-01-01 10:54:59.623       CARLINJ   both
# 4             TRAN    2019-06-24 1900-01-01 16:08:57.160       JWALTON   both
# 5             TRAN    2019-06-20 1900-01-01 10:07:06.247       CARLINJ   both
# 6             TRAN    2019-06-17 1900-01-01 15:36:18.980       CARLINJ   both
# 7             TRAN    2019-06-14 1900-01-01 08:43:36.773       CARLINJ   both
# 8             TRAN    2019-05-31 1900-01-01 08:59:52.047       CARLINJ   both
# 9             TRAN    2019-05-06 1900-01-01 11:17:07.957       CARLINJ   both
# 10            TRAN    2019-06-21 1900-01-01 08:26:28.827       CARLINJ   both
# 11            TRAN    2019-06-21 1900-01-01 15:08:12.367       CARLINJ   both
# 12            TRAN    2019-06-21 1900-01-01 15:38:55.913       CARLINJ   both
# 13            TRAN    2019-06-19 1900-01-01 16:00:13.987       CARLINJ   both
# 14             FTF    2019-07-03 1900-01-01 16:01:46.267       CARLINJ   both
# 15            TRAN    2019-06-28 1900-01-01 09:26:20.810       CARLINJ   both
# 16            TRAN    2019-06-21 1900-01-01 15:58:59.850       CARLINJ   both
# 17             FTF    2019-05-02 1900-01-01 15:30:35.610       CARLINJ   both
# 18             FTF    2019-06-20 1900-01-01 12:24:01.570       CARLINJ   both
# 19             FTF    2019-06-13 1900-01-01 10:08:33.713       CARLINJ   both
# 20             FTF    2019-05-31 1900-01-01 08:47:15.120       CARLINJ   both
# 21             FTF    2019-06-27 1900-01-01 11:35:07.563       CARLINJ   both
# 22            TRAN    2019-06-24 1900-01-01 08:24:12.540       CARLINJ   both
# 23             FTF    2019-06-27 1900-01-01 11:54:12.250       CARLINJ   both
# 24             FTF    2019-06-24 1900-01-01 16:09:18.367       JWALTON   both
# 25             FTF    2019-06-12 1900-01-01 14:27:25.830       CARLINJ   both
# 26             FTF    2019-04-18 1900-01-01 11:58:36.537       CARLINJ   both
# 27             FTF    2019-06-12 1900-01-01 14:28:24.263       CARLINJ   both
# 28            TRAN    2019-05-28 1900-01-01 13:01:03.263       CARLINJ   both
# 29             FTF    2019-05-07 1900-01-01 15:05:20.957      MGALLAGH   both
# ..             ...           ...                     ...           ...    ...
# 215           TRAN    2019-06-20 1900-01-01 10:04:29.883       CARLINJ   both
# 216            FTF    2019-05-02 1900-01-01 14:30:54.020       CARLINJ   both
# 217           TRAN    2019-07-03 1900-01-01 12:29:44.173       CARLINJ   both
# 218            FTF    2019-07-01 1900-01-01 16:28:21.423       CARLINJ   both
# 219           TRAN    2019-05-30 1900-01-01 10:28:06.240       CARLINJ   both
# 220            FTF    2019-05-08 1900-01-01 10:46:46.260       CARLINJ   both
# 221            FTF    2019-06-20 1900-01-01 11:40:49.943       CARLINJ   both
# 222            FTF    2019-06-12 1900-01-01 14:17:52.673       CARLINJ   both
# 223            FTF    2019-05-07 1900-01-01 14:51:19.510       CARLINJ   both
# 224            FTF    2019-06-12 1900-01-01 14:25:14.057       CARLINJ   both
# 225            FTF    2019-06-27 1900-01-01 11:51:19.183       CARLINJ   both
# 226            FTF    2019-05-02 1900-01-01 15:26:29.137       CARLINJ   both
# 227            FTF    2019-06-12 1900-01-01 14:29:49.553       CARLINJ   both
# 228            FTF    2019-05-30 1900-01-01 16:18:14.163       CARLINJ   both
# 229            FTF    2019-06-26 1900-01-01 12:21:33.313       CARLINJ   both
# 230           TRAN    2019-06-26 1900-01-01 13:01:09.743       CARLINJ   both
# 231            FTF    2019-06-13 1900-01-01 13:50:48.350       CARLINJ   both
# 232           TRAN    2019-06-20 1900-01-01 15:01:12.240       CARLINJ   both
# 233            FTF    2019-06-26 1900-01-01 12:07:48.537       CARLINJ   both
# 234            FTF    2019-06-12 1900-01-01 14:27:53.997       CARLINJ   both
# 235           TRAN    2019-07-03 1900-01-01 16:25:46.117       CARLINJ   both
# 236           TRAN    2019-06-14 1900-01-01 12:27:20.087       CARLINJ   both
# 237            FTF    2019-07-02 1900-01-01 07:47:34.897       CARLINJ   both
# 238            FTF    2019-06-12 1900-01-01 14:27:11.537       CARLINJ   both
# 239            FTF    2019-07-03 1900-01-01 11:00:18.497       CARLINJ   both
# 240            FTF    2019-06-20 1900-01-01 09:53:43.437       CARLINJ   both
# 241            FTF    2019-06-17 1900-01-01 10:45:58.193       CARLINJ   both
# 242            FTF    2019-06-20 1900-01-01 15:36:56.680       CARLINJ   both
# 243            FTF    2019-07-01 1900-01-01 12:35:44.270       CARLINJ   both
# 244            FTF    2019-07-08 1900-01-01 13:37:40.847       CARLINJ   both
#
# [245 rows x 31 columns]

# %%
cmp.loc[(cmp["_merge"]=="left_only")]
# Out:
# Empty DataFrame
# Columns: [PEOPLE_CODE_ID, 1_Applied, 2_Accepted, 3_Deposited, 4_Canceled, LAST_NAME, FIRST_NAME, MIDDLE_NAME, BIRTH_DATE, GOVERNMENT_ID, EMAIL_ADDRESS, ADDRESS_TYPE, ADDRESS_LINE_1, CITY, STATE, COUNTRY, ZIP_CODE, CREDITS, DEGREE, CURRICULUM, ACADEMIC_YEAR, ACADEMIC_TERM, ADMIT_YEAR, ADMIT_TERM, APP_STATUS_DATE, APP_STATUS, COLLEGE_ATTEND, REVISION_DATE, REVISION_TIME, REVISION_OPID, _merge]
# Index: []
#
# [0 rows x 31 columns]

# %%
cmp.loc[(cmp["_merge"]=="right_only")]
# Out:
# Empty DataFrame
# Columns: [PEOPLE_CODE_ID, 1_Applied, 2_Accepted, 3_Deposited, 4_Canceled, LAST_NAME, FIRST_NAME, MIDDLE_NAME, BIRTH_DATE, GOVERNMENT_ID, EMAIL_ADDRESS, ADDRESS_TYPE, ADDRESS_LINE_1, CITY, STATE, COUNTRY, ZIP_CODE, CREDITS, DEGREE, CURRICULUM, ACADEMIC_YEAR, ACADEMIC_TERM, ADMIT_YEAR, ADMIT_TERM, APP_STATUS_DATE, APP_STATUS, COLLEGE_ATTEND, REVISION_DATE, REVISION_TIME, REVISION_OPID, _merge]
# Index: []
#
# [0 rows x 31 columns]

# %%
adm_df1.loc[(adm_df1["PEOPLE_CODE_ID"]=="P000057033")]
# Out:
#      PEOPLE_CODE_ID admission_status create_date  status
# 2201     P000057033        1_Applied  2019-04-27       1
# 2202     P000057033       2_Accepted  2019-05-09       1
# 2410     P000057033      3_Deposited  2019-06-13       1

# %%
df_deposits.loc[(df_deposits["PEOPLE_CODE_ID"]=="P000057033")]
# Out:
#     PEOPLE_CODE_ID LAST_NAME FIRST_NAME MIDDLE_NAME BIRTH_DATE GOVERNMENT_ID  \
# 210     P000057033   Spencer       Evan       Reece 1994-06-15     009786809
#
#                 EMAIL_ADDRESS ADDRESS_TYPE       ADDRESS_LINE_1         CITY  \
# 210  espencer1@paulsmiths.edu         HOME  179 Pine Hill Drive  West Berlin
#
#      ... ACADEMIC_YEAR ACADEMIC_TERM ADMIT_YEAR  ADMIT_TERM APP_STATUS_DATE  \
# 210  ...          2019          FALL       2019        FALL      2019-06-13
#
#     APP_STATUS COLLEGE_ATTEND REVISION_DATE           REVISION_TIME  \
# 210        500           TRAN    2019-07-03 1900-01-01 16:25:46.117
#
#     REVISION_OPID
# 210       CARLINJ
#
# [1 rows x 26 columns]
