# %%
import pandas as pd
import numpy as np
from datetime import datetime, date
from pathlib import Path

# %%
#data_path = Path(r"\\psc-data\E\Applications\Admissions\funnel")
data_path = Path(r"E:\Applications\Admissions\funnel")

data_store = data_path / "data\stage_data"

import local_db
connection = local_db.connection()

# %%
df = pd.read_hdf("data/stage_data", key="weekly")

# %%
start_term = "2017.Spring"

# %%
df = df[(df["year_term"] > start_term)]
df = df[(df["stage"] == "Applied")]

# %%
print(df.shape)
df.head()
# Out:
# (4286, 58)
#        year_term    stage PEOPLE_CODE_ID  00  01  02  03  04  05  06  ...  45  \
# 10689  2018.Fall  Applied     P000026021   0   0   0   0   0   0   0  ...   1
# 10690  2018.Fall  Applied     P000027466   0   0   0   0   0   0   0  ...   1
# 10691  2018.Fall  Applied     P000037722   0   0   0   0   0   0   0  ...   1
# 10692  2018.Fall  Applied     P000041297   0   0   0   0   0   0   0  ...   1
# 10693  2018.Fall  Applied     P000044821   0   0   0   0   0   0   0  ...   1
#
#        46  47  48  49  50  51  52  53  curriculum
# 10689   1   1   1   1   1   1   1   1        FEFM
# 10690   1   1   1   1   1   1   1   1         NaN
# 10691   1   1   1   1   1   1   1   1         NaN
# 10692   1   1   1   1   1   1   1   1         NaN
# 10693   1   1   1   1   1   1   1   1         NaN
#
# [5 rows x 58 columns]

# %%
df.loc[
    ((df["year_term"] > start_term) & (df["stage"] == "Applied")),
    ["year_term", "stage", "PEOPLE_CODE_ID"]
].groupby(["year_term", "stage"]).count()
# Out:
#                      PEOPLE_CODE_ID
# year_term   stage
# 2018.Fall   Applied             967
# 2018.Spring Applied              33
# 2019.Fall   Applied            1031
# 2019.Spring Applied              30
# 2020.Fall   Applied            1461
# 2020.Spring Applied             107
# 2021.Fall   Applied             517
# 2021.Spring Applied             140

# %%
today = datetime.now().strftime("%Y%m%d")
print(today)
writer = pd.ExcelWriter(
    f"PowerCampus_Applied_2018-2021_{today}.xlsx"
)
# Out:
# 20210209

# %%
df.to_excel(writer, "data", index=False)

writer.save()
